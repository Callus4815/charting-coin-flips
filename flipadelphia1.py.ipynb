# %%
import random
import matplotlib.pyplot as plt
import statistics

# %%
# %matplotlib inline

def coin_flip():
    
    for _ in  range(1) :
        coin = random.randint(1,2)
        if coin == 1:
            return 'H'     
        else:            
            return 'T'

# %%
def simulator(x=16):
    count = 0
    head = []
    tail = []
    count_head = 0
    count_tail = 0
    
    while count < 2 ** x:
        coin = coin_flip()
        if coin == 'H':
            count_head+=1
        else:
            count_tail+=1
        count+=1
        for i in range(x + 1):
            if count == 2**i: 
                head.append(count_head)
                tail.append(count_tail)
    return head,  tail

head,tail = simulator()

# %%
diff = [head[i]-tail[i] for i in range(len(head))]

# %%
print(diff)
# Out:
# [-1, -2, -2, -2, -6, -6, -10, -12, -4, -32, -44, -8, 50, 144, 280, 342, 618]

# %%
x = diff
y = 17
plt.plot(x)

plt.xticks(range(17))
plt.xlabel("Number of flips")
plt.ylabel("Heads or Tails")
plt.title("Differences of Flips")

plt.show()

# %%
ratio =  [head[i]/tail[i] for i in range(len(tail)) if tail!=0]

# %%
print(ratio)
# Out:
# [0.0, 0.0, 0.3333333333333333, 0.6, 0.45454545454545453, 0.6842105263157895, 0.7297297297297297, 0.8285714285714286, 0.9692307692307692, 0.8823529411764706, 0.9176029962546817, 0.9922178988326849, 1.0247157686604054, 1.0357852882703777, 1.0347739692001987, 1.0210941836797631, 1.0190394035552544]

# %%
y  = ratio
x = 17
plt.plot(y)
plt.xlabel("Number Flips")
plt.ylabel("Ratios")
plt.title("RAtios Head to Tails")

plt.show()

# %%
y = diff
x = [2**n for n in range(17)]

plt.scatter(x,y , c='red' )
plt.xscale('log')
plt.xlabel("Number of Flips")
plt.ylabel("Differences")
plt.title("Scatter Graph")

plt.show()

# %%
counter=0
while counter < 20:
    heads, tails = simulator()
    counter+=1

# %%
ratio = [heads[i]/tails[i] for i in range(len(heads))]

# %%
mean = sum(ratio)/len(ratio)

# %%
x=mean

# %%
print(x)
# Out:
# 0.7558915224749816
